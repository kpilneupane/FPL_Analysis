# %%
import pandas as pd
import numpy as np
import requests
import json
import os

# %%
response = requests.get("https://fantasy.premierleague.com/api/bootstrap-static/")
j = response.json()
df = pd.json_normalize(j)
data = df
print(data.head())

# data.select_dtypes('object')
# data_filtered = df[['events', 'teams']]
# print(data_filtered[0])
# print(data_filtered)
# data.empty
# print(df)
# print(data.head)
# data.
# Out:
#                                               events  \
# 0  [{'id': 1, 'name': 'Gameweek 1', 'deadline_tim...
#
#                                               phases  \
# 0  [{'id': 1, 'name': 'Overall', 'start_event': 1...
#
#                                                teams  total_players  \
# 0  [{'code': 3, 'draw': 0, 'form': None, 'id': 1,...       10494086
#
#                                             elements  \
# 0  [{'chance_of_playing_next_round': 0, 'chance_o...
#
#                                        element_stats  \
# 0  [{'label': 'Minutes played', 'name': 'minutes'...
#
#                                        element_types  \
# 0  [{'id': 1, 'plural_name': 'Goalkeepers', 'plur...
#
#    game_settings.league_join_private_max  \
# 0                                     30
#
#    game_settings.league_join_public_max  \
# 0                                     5
#
#    game_settings.league_max_size_public_classic  ...  \
# 0                                            20  ...
#
#    game_settings.squad_total_spend  game_settings.ui_currency_multiplier  \
# 0                             1000                                    10
#
#    game_settings.ui_use_special_shirts  \
# 0                                False
#
#   game_settings.ui_special_shirt_exclusions  game_settings.stats_form_days  \
# 0                                        []                             30
#
#    game_settings.sys_vice_captain_enabled  game_settings.transfers_cap  \
# 0                                    True                           20
#
#    game_settings.transfers_sell_on_fee  \
# 0                                  0.5
#
#   game_settings.league_h2h_tiebreak_stats game_settings.timezone
# 0        [+goals_scored, -goals_conceded]                    UTC
#
# [1 rows x 37 columns]

# %%
# columns = data.query('forward == "salah" ')
# print(data.get('events'))
# print(j)
# print(df.head)
fpl_data = df
search_value='gameweek 1'
found_rows = pd.DataFrame()

for column in fpl_data.columns:
    try:
        mask = fpl_data[column].astype(str).str.contains(search_value,case=False)
        if mask.any():
            found_rows = pd.concat([found_rows, df[mask]], ignore_index=True)
    except Exception as e:
        print(f'Error in column "{column}": {e}')

print(found_rows)
# found_rows.to_csv('salah.csv')
# Out:
#                                               events  \
# 0  [{'id': 1, 'name': 'Gameweek 1', 'deadline_tim...
#
#                                               phases  \
# 0  [{'id': 1, 'name': 'Overall', 'start_event': 1...
#
#                                                teams  total_players  \
# 0  [{'code': 3, 'draw': 0, 'form': None, 'id': 1,...       10494086
#
#                                             elements  \
# 0  [{'chance_of_playing_next_round': 0, 'chance_o...
#
#                                        element_stats  \
# 0  [{'label': 'Minutes played', 'name': 'minutes'...
#
#                                        element_types  \
# 0  [{'id': 1, 'plural_name': 'Goalkeepers', 'plur...
#
#    game_settings.league_join_private_max  \
# 0                                     30
#
#    game_settings.league_join_public_max  \
# 0                                     5
#
#    game_settings.league_max_size_public_classic  ...  \
# 0                                            20  ...
#
#    game_settings.squad_total_spend  game_settings.ui_currency_multiplier  \
# 0                             1000                                    10
#
#    game_settings.ui_use_special_shirts  \
# 0                                False
#
#   game_settings.ui_special_shirt_exclusions  game_settings.stats_form_days  \
# 0                                        []                             30
#
#    game_settings.sys_vice_captain_enabled  game_settings.transfers_cap  \
# 0                                    True                           20
#
#    game_settings.transfers_sell_on_fee  \
# 0                                  0.5
#
#   game_settings.league_h2h_tiebreak_stats game_settings.timezone
# 0        [+goals_scored, -goals_conceded]                    UTC
#
# [1 rows x 37 columns]

# %%
# ! pip install scikit-learn

# %%
url = 'https://fantasy.premierleague.com/api/bootstrap-static/'
r = requests.get(url)
fpl_data = r.json()

# %%
# fpl_data.keys()
fpl_data = fpl_data
elements_df = pd.DataFrame(fpl_data['elements'])
elements_df.to_csv('elements.csv')
elements_df.columns
# Out:
# Index(['chance_of_playing_next_round', 'chance_of_playing_this_round', 'code',
#        'cost_change_event', 'cost_change_event_fall', 'cost_change_start',
#        'cost_change_start_fall', 'dreamteam_count', 'element_type', 'ep_next',
#        'ep_this', 'event_points', 'first_name', 'form', 'id', 'in_dreamteam',
#        'news', 'news_added', 'now_cost', 'photo', 'points_per_game',
#        'second_name', 'selected_by_percent', 'special', 'squad_number',
#        'status', 'team', 'team_code', 'total_points', 'transfers_in',
#        'transfers_in_event', 'transfers_out', 'transfers_out_event',
#        'value_form', 'value_season', 'web_name', 'minutes', 'goals_scored',
#        'assists', 'clean_sheets', 'goals_conceded', 'own_goals',
#        'penalties_saved', 'penalties_missed', 'yellow_cards', 'red_cards',
#        'saves', 'bonus', 'bps', 'influence', 'creativity', 'threat',
#        'ict_index', 'starts', 'expected_goals', 'expected_assists',
#        'expected_goal_involvements', 'expected_goals_conceded',
#        'influence_rank', 'influence_rank_type', 'creativity_rank',
#        'creativity_rank_type', 'threat_rank', 'threat_rank_type',
#        'ict_index_rank', 'ict_index_rank_type',
#        'corners_and_indirect_freekicks_order',
#        'corners_and_indirect_freekicks_text', 'direct_freekicks_order',
#        'direct_freekicks_text', 'penalties_order', 'penalties_text',
#        'expected_goals_per_90', 'saves_per_90', 'expected_assists_per_90',
#        'expected_goal_involvements_per_90', 'expected_goals_conceded_per_90',
#        'goals_conceded_per_90', 'now_cost_rank', 'now_cost_rank_type',
#        'form_rank', 'form_rank_type', 'points_per_game_rank',
#        'points_per_game_rank_type', 'selected_rank', 'selected_rank_type',
#        'starts_per_90', 'clean_sheets_per_90'],
#       dtype='object')

# %%
elements_df = pd.read_csv('elements.csv', index_col=[0])
elements_df.columns
# Out:
# Index(['chance_of_playing_next_round', 'chance_of_playing_this_round', 'code',
#        'cost_change_event', 'cost_change_event_fall', 'cost_change_start',
#        'cost_change_start_fall', 'dreamteam_count', 'element_type', 'ep_next',
#        'ep_this', 'event_points', 'first_name', 'form', 'id', 'in_dreamteam',
#        'news', 'news_added', 'now_cost', 'photo', 'points_per_game',
#        'second_name', 'selected_by_percent', 'special', 'squad_number',
#        'status', 'team', 'team_code', 'total_points', 'transfers_in',
#        'transfers_in_event', 'transfers_out', 'transfers_out_event',
#        'value_form', 'value_season', 'web_name', 'minutes', 'goals_scored',
#        'assists', 'clean_sheets', 'goals_conceded', 'own_goals',
#        'penalties_saved', 'penalties_missed', 'yellow_cards', 'red_cards',
#        'saves', 'bonus', 'bps', 'influence', 'creativity', 'threat',
#        'ict_index', 'starts', 'expected_goals', 'expected_assists',
#        'expected_goal_involvements', 'expected_goals_conceded',
#        'influence_rank', 'influence_rank_type', 'creativity_rank',
#        'creativity_rank_type', 'threat_rank', 'threat_rank_type',
#        'ict_index_rank', 'ict_index_rank_type',
#        'corners_and_indirect_freekicks_order',
#        'corners_and_indirect_freekicks_text', 'direct_freekicks_order',
#        'direct_freekicks_text', 'penalties_order', 'penalties_text',
#        'expected_goals_per_90', 'saves_per_90', 'expected_assists_per_90',
#        'expected_goal_involvements_per_90', 'expected_goals_conceded_per_90',
#        'goals_conceded_per_90', 'now_cost_rank', 'now_cost_rank_type',
#        'form_rank', 'form_rank_type', 'points_per_game_rank',
#        'points_per_game_rank_type', 'selected_rank', 'selected_rank_type',
#        'starts_per_90', 'clean_sheets_per_90'],
#       dtype='object')

# %%
cols = ['element_type', 'event_points', 'first_name','second_name', 'form', 'points_per_game', 'selected_by_percent', 'status', 'team',  'total_points', 'goals_scored', 'assists', 'yellow_cards', 'bps', 'now_cost', 'minutes']
df = elements_df[cols]
df.dtypes
# Out:
# element_type             int64
# event_points             int64
# first_name              object
# second_name             object
# form                   float64
# points_per_game        float64
# selected_by_percent    float64
# status                  object
# team                     int64
# total_points             int64
# goals_scored             int64
# assists                  int64
# yellow_cards             int64
# bps                      int64
# now_cost                 int64
# minutes                  int64
# dtype: object

# %%
cols = ['form', 'points_per_game', 'selected_by_percent']
df.loc[:, tuple(cols)].astype('float32')
# Out:
#      form  points_per_game  selected_by_percent
# 0     0.0              0.0                  0.2
# 1     0.0              0.0                  0.4
# 2     0.0              4.0                  0.1
# 3     0.0              2.6                  0.1
# 4     3.5              3.5                 16.9
# ..    ...              ...                  ...
# 764   0.0              0.0                  0.0
# 765   0.0              0.0                  0.0
# 766   0.0              0.0                  0.0
# 767   0.0              0.0                  0.0
# 768   0.0              0.0                  0.0
#
# [769 rows x 3 columns]

# %%
element_type_df = pd.DataFrame(fpl_data['element_types'])
pos_dict = dict(zip(element_type_df['id'], element_type_df['singular_name']))
df.loc[:, 'position'] = df.loc[:,'element_type'].apply(lambda x: pos_dict[x])

df['position'].value_counts().index
# Out:
# C:\Users\KNEUPANE\AppData\Local\Temp\ipykernel_2144\2470402340.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'position'] = df.loc[:,'element_type'].apply(lambda x: pos_dict[x])
# Index(['Midfielder', 'Defender', 'Forward', 'Goalkeeper'], dtype='object', name='position')

# %%
# df.loc[:, 'price'] = df.loc[:,'now_cost']/10
# df['now_cost'].head
# df.loc[:,'now_cost']/10
df.loc[:,'price'] = df.loc[:, 'now_cost']/10
# Out:
# C:\Users\KNEUPANE\AppData\Local\Temp\ipykernel_2144\192366537.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'price'] = df.loc[:, 'now_cost']/10

# %%
labels = ['Budget', 'Mid', 'Premium']
#Create bins
gk_bins = [4.0, 5.0, 6.0, 7.0]
def_bins = [4.0, 5.0, 6.0, 8.0]
mid_bins = [4.0, 6.0, 9.0, 14.0]
for_bins = [4.0, 6.0, 9.0, 14.0]

tup = [(df, gk_bins, 'Goalkeeper', labels),
       (df, def_bins, 'Defender', labels),
       (df, mid_bins, 'Midfielder', labels),
       (df, for_bins, 'Forward', labels)
       ]

#Discretinization function
def categorize_price(dataframe, bins, position, labels):
    grp = dataframe.groupby(['position']).get_group(position)
    # grp_prices = dataframe.groupby(['price'].get_group(bins))
    grp_prices = grp['price']
    grp.loc[:,'price_range'] = pd.cut(grp_prices, bins, labels=labels, right=False)
    print(grp.head)
    grp_lst.append(grp)
    
    return grp

#Create grp_list
grp_lst = list()

for item in tup:
    df = item[0]
    bins = item[1]
    pos = item[2]
    labels = item[3]
    categorize_price(df, bins, pos, labels)
    
frames = grp_lst
df = pd.concat(frames)
# print(df.head)
# Out:
# <bound method NDFrame.head of      element_type  event_points  first_name      second_name  form  \
# 15              1             0       Aaron         Ramsdale   0.0
# 16              1             0  Rúnar Alex        Rúnarsson   0.0
# 26              1             0       David      Raya Martin   2.2
# 30              1             0        Karl             Hein   0.0
# 51              1             2    Emiliano  Martínez Romero   4.3
# ..            ...           ...         ...              ...   ...
# 726             1             0      Joseph            Anang   0.0
# 732             1             0      Daniel          Bentley   2.3
# 748             1             0         Tom             King   0.0
# 752             1             0        José   Malheiro de Sá   1.0
# 754             1             0      Matija           Šarkić   0.0
#
#      points_per_game  selected_by_percent status  team  total_points  \
# 15               3.4                  6.4      a     1            17
# 16               0.0                  0.1      u     1             0
# 26               3.7                  5.7      a     1            48
# 30               0.0                  0.1      a     1             0
# 51               3.3                 11.7      a     2            60
# ..               ...                  ...    ...   ...           ...
# 726              0.0                  0.1      a    19             0
# 732              5.3                  1.3      a    20            16
# 748              0.0                  0.7      a    20             0
# 752              2.7                  1.3      a    20            43
# 754              0.0                  0.3      u    20             0
#
#      goals_scored  assists  yellow_cards  bps  now_cost  minutes    position  \
# 15              0        0             0   77        46      450  Goalkeeper
# 16              0        0             0    0        40        0  Goalkeeper
# 26              0        0             0  216        49     1170  Goalkeeper
# 30              0        0             0    0        40        0  Goalkeeper
# 51              0        0             3  332        52     1620  Goalkeeper
# ..            ...      ...           ...  ...       ...      ...         ...
# 726             0        0             0    0        40        0  Goalkeeper
# 732             0        0             0   60        39      247  Goalkeeper
# 748             0        0             0    0        39        0  Goalkeeper
# 752             0        0             1  251        50     1372  Goalkeeper
# 754             0        0             0    0        40        0  Goalkeeper
#
#      price price_range
# 15     4.6      Budget
# 16     4.0      Budget
# 26     4.9      Budget
# 30     4.0      Budget
# 51     5.2         Mid
# ..     ...         ...
# 726    4.0      Budget
# 732    3.9         NaN
# 748    3.9         NaN
# 752    5.0         Mid
# 754    4.0      Budget
#
# [88 rows x 19 columns]>
# <bound method NDFrame.head of      element_type  event_points    first_name           second_name  form  \
# 1               2             0        Cédric          Alves Soares   0.0
# 4               2             0       Gabriel  dos Santos Magalhães   3.5
# 8               2             0         Jakub                Kiwior   0.5
# 18              2             0       William                Saliba   2.2
# 20              2             0        Kieran               Tierney   0.0
# ..            ...           ...           ...                   ...   ...
# 755             2             0        Nélson         Cabral Semedo   2.3
# 756             2             0  Toti António                 Gomes   2.1
# 759             2             0          Matt               Doherty   1.9
# 760             2             0      Santiago                 Bueno   0.3
# 766             2             0        Justin                Hubner   0.0
#
#      points_per_game  selected_by_percent status  team  total_points  \
# 1                0.0                  0.4      a     1             0
# 4                3.5                 16.9      a     1            56
# 8                1.7                  0.1      a     1            12
# 18               4.1                 36.3      a     1            74
# 20               0.0                  0.1      u     1             0
# ..               ...                  ...    ...   ...           ...
# 755              1.9                  0.7      a    20            32
# 756              2.1                  0.2      a    20            32
# 759              1.5                  0.2      a    20            18
# 760              1.0                  0.0      a    20             2
# 766              0.0                  0.0      a    20             0
#
#      goals_scored  assists  yellow_cards  bps  now_cost  minutes  position  \
# 1               0        0             0    0        39        0  Defender
# 4               1        0             1  259        50     1284  Defender
# 8               0        0             0   58        43      247  Defender
# 18              1        1             1  349        56     1620  Defender
# 20              0        0             0    0        44        0  Defender
# ..            ...      ...           ...  ...       ...      ...       ...
# 755             0        1             4  210        45     1488  Defender
# 756             0        1             1  172        44     1102  Defender
# 759             1        0             1   63        43      384  Defender
# 760             0        0             0   19        45      110  Defender
# 766             0        0             0    0        40        0  Defender
#
#      price price_range
# 1      3.9         NaN
# 4      5.0         Mid
# 8      4.3      Budget
# 18     5.6         Mid
# 20     4.4      Budget
# ..     ...         ...
# 755    4.5      Budget
# 756    4.4      Budget
# 759    4.3      Budget
# 760    4.5      Budget
# 766    4.0      Budget
#
# [249 rows x 19 columns]>
# <bound method NDFrame.head of      element_type  event_points   first_name       second_name  form  \
# 2               3             0      Mohamed            Elneny   0.0
# 3               3             0        Fábio   Ferreira Vieira   0.0
# 5               3             0          Kai           Havertz   3.2
# 7               3             0   Jorge Luiz      Frello Filho   0.2
# 9               3             0       Marcus  Oliveira Alencar   0.0
# ..            ...           ...          ...               ...   ...
# 763             3             0  Jean-Ricner        Bellegarde   1.6
# 764             3             0      Matthew       Whittingham   0.0
# 765             3             0      Tawanda           Chirewa   0.0
# 767             3             0         Owen           Hesketh   0.0
# 768             3             0           Ty           Barnett   0.0
#
#      points_per_game  selected_by_percent status  team  total_points  \
# 2                4.0                  0.1      a     1             4
# 3                2.6                  0.1      i     1            21
# 5                2.8                  1.6      s     1            50
# 7                1.4                  0.2      a     1            15
# 9                0.0                  0.0      u     1             0
# ..               ...                  ...    ...   ...           ...
# 763              2.2                  0.0      d    20            20
# 764              0.0                  0.0      a    20             0
# 765              0.0                  0.0      a    20             0
# 767              0.0                  0.0      a    20             0
# 768              0.0                  0.0      a    20             0
#
#      goals_scored  assists  yellow_cards  bps  now_cost  minutes    position  \
# 2               0        1             0   12        44        1  Midfielder
# 3               1        3             0   62        54      236  Midfielder
# 5               4        1             5  146        71     1092  Midfielder
# 7               0        0             1   66        53      383  Midfielder
# 9               0        0             0    0        45        0  Midfielder
# ..            ...      ...           ...  ...       ...      ...         ...
# 763             1        1             0   76        49      460  Midfielder
# 764             0        0             0    0        45        0  Midfielder
# 765             0        0             0    0        45        0  Midfielder
# 767             0        0             0    0        45        0  Midfielder
# 768             0        0             0    0        45        0  Midfielder
#
#      price price_range
# 2      4.4      Budget
# 3      5.4      Budget
# 5      7.1         Mid
# 7      5.3      Budget
# 9      4.5      Budget
# ..     ...         ...
# 763    4.9      Budget
# 764    4.5      Budget
# 765    4.5      Budget
# 767    4.5      Budget
# 768    4.5      Budget
#
# [334 rows x 19 columns]>
# <bound method NDFrame.head of      element_type  event_points first_name               second_name  form  \
# 0               4             0    Folarin                   Balogun   0.0
# 6               4             0    Gabriel         Fernando de Jesus   4.3
# 11              4             0      Eddie                   Nketiah   1.0
# 41              4             0     Keinan                     Davis   0.0
# 46              4             1       Jhon                     Durán   0.5
# ..            ...           ...        ...                       ...   ...
# 720             4             0   Gianluca                  Scamacca   0.0
# 738             4             0      Fábio                     Silva   0.0
# 746             4             0       Sasa                 Kalajdzic   0.4
# 758             4             0    Matheus  Santos Carneiro Da Cunha   4.1
# 762             4             0     Nathan                    Fraser   0.0
#
#      points_per_game  selected_by_percent status  team  total_points  \
# 0                0.0                  0.2      u     1             0
# 6                3.5                  5.6      a     1            46
# 11               3.4                  5.0      a     1            57
# 41               0.0                  0.1      u     2             0
# 46               1.6                  0.2      a     2            19
# ..               ...                  ...    ...   ...           ...
# 720              0.0                  0.0      u    19             0
# 738              1.0                  0.2      d    20             8
# 746              2.2                  0.2      a    20            24
# 758              3.8                  6.4      a    20            68
# 762              0.0                  0.1      a    20             0
#
#      goals_scored  assists  yellow_cards  bps  now_cost  minutes position  \
# 0               0        0             0    0        44        0  Forward
# 6               3        2             3  144        80      821  Forward
# 11              5        3             3  175        53      842  Forward
# 41              0        0             0    0        49        0  Forward
# 46              2        0             4   64        50      140  Forward
# ..            ...      ...           ...  ...       ...      ...      ...
# 720             0        0             0    0        60        0  Forward
# 738             0        0             2    7        53      259  Forward
# 746             2        0             0   88        49      158  Forward
# 758             5        3             3  246        58     1504  Forward
# 762             0        0             0    0        45        0  Forward
#
#      price price_range
# 0      4.4      Budget
# 6      8.0         Mid
# 11     5.3      Budget
# 41     4.9      Budget
# 46     5.0      Budget
# ..     ...         ...
# 720    6.0         Mid
# 738    5.3      Budget
# 746    4.9      Budget
# 758    5.8      Budget
# 762    4.5      Budget
#
# [98 rows x 19 columns]>
# C:\Users\KNEUPANE\AppData\Local\Temp\ipykernel_2144\2721001087.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grp.loc[:,'price_range'] = pd.cut(grp_prices, bins, labels=labels, right=False)
# C:\Users\KNEUPANE\AppData\Local\Temp\ipykernel_2144\2721001087.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grp.loc[:,'price_range'] = pd.cut(grp_prices, bins, labels=labels, right=False)
# C:\Users\KNEUPANE\AppData\Local\Temp\ipykernel_2144\2721001087.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grp.loc[:,'price_range'] = pd.cut(grp_prices, bins, labels=labels, right=False)
# C:\Users\KNEUPANE\AppData\Local\Temp\ipykernel_2144\2721001087.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grp.loc[:,'price_range'] = pd.cut(grp_prices, bins, labels=labels, right=False)

# %%
# creating labels
labels = ['Differential', 'High']

# Creating range
selected_by = [0.0, 15.0, 99.0]

# create list of tuples
tup = (df, selected_by, labels)

# Distinction function
def categorize_own(dataframe, bins, labels):
    ownership = dataframe['selected_by_percent']
    dataframe['ownership'] = pd.cut(ownership, bins, labels=labels, right=False)
    return dataframe

categorize_own(df, selected_by, labels)
# Out:
#      element_type  event_points  first_name               second_name  form  \
# 15              1             0       Aaron                  Ramsdale   0.0
# 16              1             0  Rúnar Alex                 Rúnarsson   0.0
# 26              1             0       David               Raya Martin   2.2
# 30              1             0        Karl                      Hein   0.0
# 51              1             2    Emiliano           Martínez Romero   4.3
# ..            ...           ...         ...                       ...   ...
# 720             4             0    Gianluca                  Scamacca   0.0
# 738             4             0       Fábio                     Silva   0.0
# 746             4             0        Sasa                 Kalajdzic   0.4
# 758             4             0     Matheus  Santos Carneiro Da Cunha   4.1
# 762             4             0      Nathan                    Fraser   0.0
#
#      points_per_game  selected_by_percent status  team  total_points  \
# 15               3.4                  6.4      a     1            17
# 16               0.0                  0.1      u     1             0
# 26               3.7                  5.7      a     1            48
# 30               0.0                  0.1      a     1             0
# 51               3.3                 11.7      a     2            60
# ..               ...                  ...    ...   ...           ...
# 720              0.0                  0.0      u    19             0
# 738              1.0                  0.2      d    20             8
# 746              2.2                  0.2      a    20            24
# 758              3.8                  6.4      a    20            68
# 762              0.0                  0.1      a    20             0
#
#      goals_scored  assists  yellow_cards  bps  now_cost  minutes    position  \
# 15              0        0             0   77        46      450  Goalkeeper
# 16              0        0             0    0        40        0  Goalkeeper
# 26              0        0             0  216        49     1170  Goalkeeper
# 30              0        0             0    0        40        0  Goalkeeper
# 51              0        0             3  332        52     1620  Goalkeeper
# ..            ...      ...           ...  ...       ...      ...         ...
# 720             0        0             0    0        60        0     Forward
# 738             0        0             2    7        53      259     Forward
# 746             2        0             0   88        49      158     Forward
# 758             5        3             3  246        58     1504     Forward
# 762             0        0             0    0        45        0     Forward
#
#      price price_range     ownership
# 15     4.6      Budget  Differential
# 16     4.0      Budget  Differential
# 26     4.9      Budget  Differential
# 30     4.0      Budget  Differential
# 51     5.2         Mid  Differential
# ..     ...         ...           ...
# 720    6.0         Mid  Differential
# 738    5.3      Budget  Differential
# 746    4.9      Budget  Differential
# 758    5.8      Budget  Differential
# 762    4.5      Budget  Differential
#
# [769 rows x 20 columns]

# %%
# check for missing data

df.isnull().sum()
# Out:
# element_type            0
# event_points            0
# first_name              0
# second_name             0
# form                    0
# points_per_game         0
# selected_by_percent     0
# status                  0
# team                    0
# total_points            0
# goals_scored            0
# assists                 0
# yellow_cards            0
# bps                     0
# now_cost                0
# minutes                 0
# position                0
# price                   0
# price_range            46
# ownership               0
# dtype: int64

# %%
df.to_csv('Data/23_24/cleaned_data.csv', index=False)

# %%
# teams
# teams_df = pd.DataFrame(fpl_data['teams'])
# teams_df.to_csv('tams_23_24.csv')
# print(teams_df.head)

# %%
# teams_df = pd.read_csv('teams.csv', index_col=[0])
# teams_df.head

# %%
# teams_df.columns
